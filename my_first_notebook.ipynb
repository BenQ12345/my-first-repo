# %%
Hardware: These are the physical parts of a computer that you can see and touch.
Example: keyboard
Software: These are the programs or instructions that tell the hardware what to do.
Example: word
